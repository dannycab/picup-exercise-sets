# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
# %matplotlib inline

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

# %%
k = 9e9
q1 = 1e-9
x1 = 0
y1 = 0
extent = 1e-4

spacing = 1e-6
x = np.arange(-extent,extent,spacing)
y = np.arange(-extent,extent,spacing)

# %%
X,Y = np.meshgrid(x,y)

# %%
V = k*q1/np.sqrt((X-x1)**2+(Y-y1)**2)

# %%
plt.figure()
CS = plt.contour(X, Y, V,levels=np.arange(0,10e5,1e5))
plt.title('Energy contours for point charge')
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));
CB = plt.colorbar(CS, shrink=0.8, extend='both');

# %%
k = 9e9
q1 = 1e-9
x1 = 0
y1 = 1e-5
q2 = -1e-9
x2 = 0
y2 = -1e-5
extent = 1e-4

spacing = 1e-6
x = np.arange(-extent,extent,spacing)
y = np.arange(-extent,extent,spacing)

X,Y = np.meshgrid(x,y)

# %%
V = k*q1/np.sqrt((X-x1)**2+(Y-y1)**2)+k*q2/np.sqrt((X-x2)**2+(Y-y2)**2)

# %%
plt.figure()
CS = plt.contour(X, Y, V,levels=np.arange(-10e5,10e5,1e5))
plt.title('Energy contours for dipole')
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));
CB = plt.colorbar(CS, shrink=0.8, extend='both');

# %%
k = 9e9

q1 = 1e-9
x1 = 1e-5
y1 = 1e-5

q2 = -1e-9
x2 = 1e-5
y2 = -1e-5

q3 = 1e-9
x3 = -1e-5
y3 = -1e-5

q4 = -1e-9
x4 = -1e-5
y4 = 1e-5

extent = 1e-4

spacing = 1e-6
x = np.arange(-extent,extent,spacing)
y = np.arange(-extent,extent,spacing)

X,Y = np.meshgrid(x,y)

# %%
V = k*q1/np.sqrt((X-x1)**2+(Y-y1)**2)+k*q2/np.sqrt((X-x2)**2+(Y-y2)**2)+\
k*q3/np.sqrt((X-x3)**2+(Y-y3)**2)+k*q4/np.sqrt((X-x4)**2+(Y-y4)**2)

# %%
CS = plt.contour(X, Y, V,levels=np.arange(-1e8,1e8,1e6))
#plt.clabel(CS, inline=1, fontsize=10)
plt.title('Energy contours for quadrapole')
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));
CB = plt.colorbar(CS, shrink=0.8, extend='both');

# %%
im = plt.imshow(V, interpolation='none', cmap=cm.viridis)
CS = plt.contour(X,Y,V)
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));

# make a colorbar for the contour lines
CB = plt.colorbar(CS, shrink=0.8, extend='both')

# We can still add a colorbar for the image, too.
CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)

# %%
k = 9e9

q1 = 1e-9
x1 = 1e-5
y1 = 1e-5

q2 = -1e-9
x2 = 1e-5
y2 = -1e-5

q3 = -1e-9
x3 = -1e-5
y3 = -1e-5

q4 = -1e-9
x4 = -1e-5
y4 = 1e-5

extent = 1e-4

spacing = 1e-6
x = np.arange(-extent,extent,spacing)
y = np.arange(-extent,extent,spacing)

X,Y = np.meshgrid(x,y)

# %%
V = k*q1/np.sqrt((X-x1)**2+(Y-y1)**2)+k*q2/np.sqrt((X-x2)**2+(Y-y2)**2)+\
k*q3/np.sqrt((X-x3)**2+(Y-y3)**2)+k*q4/np.sqrt((X-x4)**2+(Y-y4)**2)

# %%
CS = plt.contour(X, Y, V,levels=np.arange(-1e8,1e8,1e6))
#plt.clabel(CS, inline=1, fontsize=10)
plt.title('Energy contours for quadrapole')
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));
CB = plt.colorbar(CS, shrink=0.8, extend='both');

# %%
im = plt.imshow(V, interpolation='none', cmap=cm.viridis)
CS = plt.contour(X,Y,V,levels=np.arange(-1e8,1e8,1e6))
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));

# make a colorbar for the contour lines
CB = plt.colorbar(CS, shrink=0.8, extend='both')

# We can still add a colorbar for the image, too.
CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)

# %%
start = time.time()
k = 9e9;

extent = 1e-3;
spacing = 1e-6;

x = np.arange(-extent,extent,spacing);
y = np.arange(-extent,extent,spacing);

X,Y = np.meshgrid(x,y);

N = 100;
V = 0;

for i in np.arange(0,N):
    
    qsign = np.random.random_integers(-1,high=1);
    while qsign == 0:
        qsign = np.random.random_integers(-1,high=1);
    
    xsign = np.random.random_integers(-1,high=1);
    while xsign == 0:
        xsign = np.random.random_integers(-1,high=1);
    
    ysign = np.random.random_integers(-1,high=1);
    while ysign == 0:
        ysign = np.random.random_integers(-1,high=1);
    
    qr = qsign*np.random.random()*1e-9;
    xr = xsign*np.random.random()*extent;
    yr = ysign*np.random.random()*extent;
    V += k*qr/np.sqrt((X-xr)**2+(Y-yr)**2)
end = time.time()
end-start
# Out:
# 10.811908960342407

# %%
start=time.time()
CS = plt.contour(X, Y, V,levels=np.arange(-5e7,5e7,1e5))
#plt.clabel(CS, inline=1, fontsize=10)
plt.title('Energy contours for random charges')
frac=1
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));
CB = plt.colorbar(CS, shrink=0.8, extend='both');
end=time.time()
end-start
# Out:
# 51.423277139663696

# %%
start=time.time()
im = plt.imshow(V, interpolation='none', cmap=cm.viridis)
CS = plt.contour(X,Y,V,levels=np.arange(-5e7,5e7,1e5))
frac=0.2
plt.xlim((-frac*extent,frac*extent));
plt.ylim((-frac*extent,frac*extent));

# make a colorbar for the contour lines
CB = plt.colorbar(CS, shrink=0.8, extend='both')

# We can still add a colorbar for the image, too.
CBI = plt.colorbar(im, orientation='horizontal', shrink=0.8)
end=time.time()
end-start
# Out:
# 57.771186113357544

# %%
start=time.time()
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, V, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
#fig.colorbar(surf, shrink=0.5, aspect=5)
end=time.time()
end-start
# Out:
# 139.35939383506775
